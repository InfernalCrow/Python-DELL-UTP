# %% [markdown]
# ![Data Science Black@300x.png](https://i.imgur.com/KIHm5UF.png)
#
# # Condicionales
#
# Cuando escribimos código Python es posible ejecutar instrucciones dependiendo de que una condicion especifica.
#
# ## Indentacion
#
# En Python verás que cada espacio de código esta identado osea, que dejamos espacio para identificar los bloques de código. Esto es parte de la syntaxis de Python.

# %%
nombre = "Maxs"

if nombre == "Maxs":
  print("Hola Maxs!") # Este bloque de código debe estar espaciado al principio, por mejor practica se usan siempre 4 espacios
# Out:
# Hola Maxs!

# %% [markdown]
# # IF STATEMENT
#
# Es un bloque de codigo que nos permite controlar el camino que la computadora cuando ejecuta el codigo

# %%
clima = input("""
Como esta el clima?
- soleado
- lluvioso
- nublado
""")

if clima == "soleado":
    print ("El dia esta soleado, podemos ir al parque🌞🏞️🚶 ")
# Out:
# el lunes cae la lluvia,entonces no hay escuela

# %%
num = 10
if num > 0:
    print(num, "is a positive number.")
print("This is always printed.")

num = -5
if num > 0:
    print(num, "is a positive number.")
print("This is also always printed.")
# Out:
# 10 is a positive number.
# This is always printed.
# This is also always printed.

# %% [markdown]
# # ELSE
#
# Es una forma de ejecutar código si la condicion if no se cumple

# %%
clima = input("""
Como esta el clima?
- soleado
- lluvioso
- nublado
""")

if clima == "soleado":
    print ("El dia esta soleado, podemos ir al parque🌞🏞️🚶 ")
else:
    print("No conozco ese clima 🤔")

# %%
edad = 18

if edad >= 18:
    print("Eres mayor de edad!")
else:
    print("Todavia eres menor de edad!")

# %% [markdown]
# # ELIF
#
# Con esta condición `elif` agregamos la posibilidad de incluir una condicion si la primera no se cumple.

# %%
clima = input("""
Como esta el clima?
- soleado
- lluvioso
- nublado
""")

if clima == "soleado":
    print ("El dia esta soleado, podemos ir al parque🌞🏞️🚶 ")
elif clima == "lluvioso":
    print ("El dia esta lluvioso, mejor nos quedamos en la casa 🏠⛈️")
elif clima == "nublado":
    print("El dia esta nublado, ten cuidado con los rayos ⚡")
else:
    print("No conozco ese clima 🤔")

# %%
edad = 24

if edad >= 18:
    print("Eres mayor de edad!")
elif edad >= 0:
    print("Todavia eres menor de edad!")
else:
    print("Edad inválida!")
# Out:
# Eres mayor de edad!

# %% [markdown]
# # Ejercicios

# %% [markdown]
# Vamos a ver un programa que adivina tu numero:

# %%
import random

Numero_Adivinado = input('Adivina un numero del 1 al 10 ')
Numero_Ganador = random.randint(1, 10)

if Numero_Adivinado == str(Numero_Ganador):
    print('Feliciadades lo has logrado')
elif float(Numero_Adivinado) >= 11:
    print('Leistes bien?')
else:
    print('El numero ganador era {}'.format(Numero_Ganador))
# Out:
# Adivina un numero del 1 al 10 7
# El numero ganador era 1

# %% [markdown]
# # Talleres

# %% [markdown]
# 1. Escribe un programa en Python para convertir temperaturas a y desde celsius, fahrenheit.
#
# [Fórmula : c/5 = f-32/9 [ donde c = temperatura en celsius y f = temperatura en fahrenheit ]
#
# Resultado esperado :
# 60°C es 140 en Fahrenheit
# 45°F es 7 en Celsius

# %%
print("Programa Para convertir Temperaturas")
print("Ingrese C para convertir de Celsius a fahrenheit")
print("Ingrese F para Convertir de Fahrenheit a Celcius")
condicion=input()

if condicion.lower() == "c":
  
    print ("Ingrese la Temperatura en Celsius")
    tem_c=float(input())
    temperatura_f=float(tem_c*1.8+32)
    print("La Temperatura en Fahrenheit ES: {0}".format(temperatura_f))
    
elif condicion.upper() == "F":
  
    print ("Ingrese la Temperatura en Fahrenheit")
    tem_f=float(input())
    temperatura_c=float(tem_f-32)/1.8
    print("La Temperatura en Celsius ES: {0}".format(int(temperatura_c)))

else:
    print("Error, no existe esa temperatura")
# Out:
# Programa Para convertir Temperaturas
# Ingrese C para convertir de Celsius a fahrenheit
# Ingrese F para Convertir de Fahrenheit a Celcius
# C
# Ingrese la Temperatura en Celsius
# 34
# La Temperatura en Fahrenheit ES: 93.2

# %% [markdown]
# 2. Escribe un programa en Python para calcular la edad de un perro en años de perro
# Nota: Durante los dos primeros años, un año canino equivale a 10,5 años humanos. Después, cada año canino equivale a 4 años humanos.
# Resultado esperado:
#
# Introduzca la edad de un perro en años humanos: 15
# La edad del perro en años de perro es 73

# %%
anios = int(input("Años humanos?: "))

edad_perro = 2*10.5

if anios > 2:
  edad_perro += (anios - 2)*4

print("La edad en años perro es", int(edad_perro))
# Out:
# Años humanos?: 6
# La edad en años perro es 37

# %% [markdown]
# 3. Escribe un programa en Python para comprobar si un alfabeto es una vocal o una consonante
# Salida esperada:
#
# Introduce una letra del alfabeto: k
# k es una consonante.

# %%
print('escribe una letra:', end="")
letra = input()  
if letra == 'a' or letra == 'e' or letra == 'i' or  letra == 'o' or letra == 'u':
    print(letra, " es un Vocal")
elif letra == 'b' or letra == 'c' or letra == 'd' or letra == 'f' or letra == 'g' or letra == 'h' or letra == 'j' or letra == 'k' or letra == 'l' or letra == 'm' or letra =='n' or letra == 'ñ' or letra == 'p' or letra == 'q' or letra == 's' or letra == 'r' or letra == 't' or letra == 'v' or letra == 'w' or letra == 'x' or letra == 'y' or letra == 'z':
    print(letra, " es una consonante")
else:
    print("no es una letra")
# Out:
# escribe una letra:q
# q  es una consonante

# %% [markdown]
# 4. Escribe un programa en Python para convertir el nombre del mes en un número de días
# Salida esperada:
#
# Lista de meses: Enero, Febrero, Marzo, Abril, Mayo, Junio, Julio, Agosto
# , septiembre, octubre, noviembre, diciembre
# Introduzca el nombre del mes: Febrero
# Número de días: 28/29 días

# %%
print('escribe el mes:', end="")
mes = input() 
if mes == 'Enero':
  print (" Enero")
  print ("31 dias")
elif mes == 'Febrero':
  print (" Febrero")
  print ("31 dias")
elif mes == 'Marzo':
  print (" Marzo")
  print ("31 dias")
elif mes == 'Abril':  
  print (" Abril")
  print ("30 dias")
elif mes == 'Mayo':
  print (" Mayo")
  print ("31 dias")
elif mes == 'Junio':
  print (" Junio")
  print ("30 dias")
elif mes == 'Julio':
  print (" Julio")
  print ("31 dias")
elif mes == 'Agosto':
  print (" Agosto")
  print ("31 dias")     
elif mes == 'Septiembre':
  print (" Septiembre")
  print ("30 dias")
elif mes == 'Octubre':
  print (" Octubre")
  print ("31 dias") 
elif mes == 'Noviembre':
  print (" Noviembre")
  print ("30 dias")
elif mes == 'Diciembre':  
  print (" Diciembre")
  print ("31 dias")  
else:
  print("no existe este mes")
# Out:
# escribe el mes:Enero
#  Enero
# 31 dias
